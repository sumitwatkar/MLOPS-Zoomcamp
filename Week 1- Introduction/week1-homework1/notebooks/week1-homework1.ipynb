# %% [markdown]
# # MLOps Zoomcamp 2023 - Homework #1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings; warnings.simplefilter('ignore')

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_parquet('yellow_tripdata_2022-01.parquet')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %% [markdown]
# ### Exploring the Dataset

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
df.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                     float64
# dtype: object

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1         1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2         2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3         2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4         2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           3.80         1.0                  N           142           236
# 1           2.10         1.0                  N           236            42
# 2           0.97         1.0                  N           166           166
# 3           1.09         1.0                  N           114            68
# 4           4.30         1.0                  N            68           163
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %% [markdown]
# # Question 1: Number of columns in Jan 2022 Yellow Taxi Trip data

# %%
df.shape
# Out:
# (2463931, 19)

# %% [markdown]
# ## There are 19 columns in Jan 2022 Yellow Taxi Trip data.

# %% [markdown]
# #  Qu. 2 : Standard deviation of the trips duration in Jan 2022 Yellow Taxi Trip

# %% [markdown]
#    #### Target Variable:
#
# - trip_duration —> duration of the trip in seconds

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1         1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2         2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3         2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4         2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           3.80         1.0                  N           142           236
# 1           2.10         1.0                  N           236            42
# 2           0.97         1.0                  N           166           166
# 3           1.09         1.0                  N           114            68
# 4           4.30         1.0                  N            68           163
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df['trip_duration'] = df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']
df['trip_duration'] = df['trip_duration'].apply(lambda td: td.total_seconds() / 60)

# %%
df['trip_duration'].std()
# Out:
# 46.44530513776499

# %% [markdown]
# ## Standard deviation of the trip_duration is 46.45

# %% [markdown]
# ### Outliers Detection & Treatment:
#
# - Next, we need to check the distribution of the trip_duration.

# %%
# Checking for a statistical summary of the dataset

df['trip_duration'].describe()
# Out:
# count    2.463931e+06
# mean     1.421220e+01
# std      4.644531e+01
# min     -3.442400e+03
# 25%      6.316667e+00
# 50%      1.018333e+01
# 75%      1.616667e+01
# max      8.513183e+03
# Name: trip_duration, dtype: float64

# %%
sns.boxplot(df['trip_duration'])
# Out:
# <AxesSubplot:xlabel='trip_duration'>

# %% [markdown]
# - There are some outliers. Let's remove them and keep only the records where the duration was between 1 and 60 minutes.

# %%
df = df[(df.trip_duration >= 1) & (df.trip_duration <= 60)]

# %%
df['trip_duration'].sort_values(ascending=False)
# Out:
# 2408850    60.0
# 2398726    60.0
# 2406323    60.0
# 975774     60.0
# 2434276    60.0
#            ...
# 1674445     1.0
# 2164437     1.0
# 2164436     1.0
# 2435455     1.0
# 858380      1.0
# Name: trip_duration, Length: 2421440, dtype: float64

# %%
df.shape
# Out:
# (2421440, 20)

# %% [markdown]
# # Question 3: Fraction of the records left after dropping the outliers
#
# - Total number of records in the dataset : 2463931
# - Number of records left after dropping the outliers : 2421440

# %%
(2421440 / 2463931 ) * 100
# Out:
# 98.27547930522405

# %% [markdown]
# ## The fraction of records left after dropping the outliers is approximately 98%.

# %% [markdown]
# # Question 4: Dimensionality after OHE

# %% [markdown]
# - Let's apply one-hot encoding to the pickup and dropoff location IDs. We'll use only these two features for our model.

# %%
df.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                     float64
# trip_duration                   float64
# dtype: object

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %%
categorical = ['PULocationID', 'DOLocationID']

df[categorical] = df[categorical].astype(str)

# %%
train_dicts = df[categorical].to_dict(orient='records')

dv = DictVectorizer()

X_train = dv.fit_transform(train_dicts)

# %%
X_train.shape
# Out:
# (2421440, 515)

# %% [markdown]
# ## Total  number of columns are 515.

# %% [markdown]
# # Question 5: RMSE on train:

# %% [markdown]
# ### Training a model:
#
# - Train linear regression model with default parameters & calculate the RMSE of the model on the training data

# %%
target = 'trip_duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 6.986190830136929

# %% [markdown]
# ## RMSE on train is 6.99

# %% [markdown]
# # Question 6: RMSE on validation:

# %% [markdown]
# ### Evaluating the model:
#
# - Now, let's apply this model to the validation dataset (February 2022).

# %%
df1 = pd.read_parquet('yellow_tripdata_2022-02.parquet')

# %%
df1
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-02-01 00:06:58   2022-02-01 00:19:24              1.0
# 1               1  2022-02-01 00:38:22   2022-02-01 00:55:55              1.0
# 2               1  2022-02-01 00:03:20   2022-02-01 00:26:59              1.0
# 3               2  2022-02-01 00:08:00   2022-02-01 00:28:05              1.0
# 4               2  2022-02-01 00:06:48   2022-02-01 00:33:07              1.0
# ...           ...                  ...                   ...              ...
# 2979426         2  2022-02-28 23:50:00   2022-03-01 00:06:00              NaN
# 2979427         2  2022-02-28 23:06:57   2022-02-28 23:19:12              NaN
# 2979428         2  2022-02-28 23:48:13   2022-03-01 00:03:33              NaN
# 2979429         2  2022-02-28 23:56:41   2022-03-01 00:04:57              NaN
# 2979430         2  2022-02-28 23:04:00   2022-02-28 23:10:00              NaN
#
# ...

# %%
df1['trip_duration'] = df1['tpep_dropoff_datetime'] - df1['tpep_pickup_datetime']
df1['trip_duration'] = df1['trip_duration'].apply(lambda td: td.total_seconds() / 60)

# %%
df1['trip_duration'].sort_values(ascending=False)
# Out:
# 34510      5489.383333
# 2393967    5272.050000
# 2976363    4260.583333
# 1360674    2950.816667
# 2966589    2759.533333
#               ...
# 2907664      -0.966667
# 2959503      -0.966667
# 2959037      -0.983333
# 2936263      -0.983333
# 2963035      -0.983333
# Name: trip_duration, Length: 2979431, dtype: float64

# %%
df1 = df1[(df1.trip_duration >= 1) & (df1.trip_duration <= 60)]

# %%
categorical1 = ['PULocationID', 'DOLocationID']

df1[categorical1] = df1[categorical1].astype(str)

# %%
df1['trip_duration'].sort_values(ascending=False)
# Out:
# 2885814    60.0
# 1561768    60.0
# 2396257    60.0
# 2940054    60.0
# 2906417    60.0
#            ...
# 2159861     1.0
# 437654      1.0
# 2942158     1.0
# 1971366     1.0
# 560415      1.0
# Name: trip_duration, Length: 2918187, dtype: float64

# %%
test_dicts = df1[categorical1].to_dict(orient='records')

dv = DictVectorizer()

X_valid = dv.fit_transform(test_dicts)

# %%
target1 = 'trip_duration'
y_valid = df1[target1].values

lr = LinearRegression()
lr.fit(X_valid, y_valid)

y_pred1 = lr.predict(X_valid)

mean_squared_error(y_valid, y_pred1, squared=False)
# Out:
# 7.639501151031967

# %% [markdown]
# ## RMSE on validation is 7.63
